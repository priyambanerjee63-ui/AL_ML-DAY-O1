# %%
print("Hello World")

# %%
a = int(input("Enter first Number:"))
b = int(input("Enter second number"))
print("Addition =", a+b)
print("Substraction =")

# %%
# Build a Calculator
# Concepts: Type Casting, Variable, Data Types, I/O functions
a = int(input("Enter first Number: "))
b = int(input("Enter second number: "))
print("Addition is: ", a+b)
print(f"Addition is: {a+b}") # F- String (Very Crucial)
print(f"Subtraction is: {a-b}")
print("Multiplication is: {*b}")
print("Division is: {a/b}")
# Out:
# Enter first Number: 300
# Enter second number: 400
# Addition is:  700
# Addition is: 700
# Subtraction is: -100
# Multiplication is: {a*b}
# Division is: {a/b}

# %%
*
# Out:
#   File "/tmp/ipykernel_574/796671574.py", line 1
#     *
#      ^
# SyntaxError: invalid syntax

# %%
name = input("Enter your name:")
age = int(input("Enter Your age: "))
dept = input("Enter Your Deparment")
print(f"my name is (name), age is (age),deparment is (dept)")
# Out:
# Enter your name:priyam
# Enter Your age: 20
# Enter Your Deparmentece
# my name is (name), age is (age),deparment is (dept)

# %%
  #take two numbers and print their sum
  a=float(input(" the first number is: "))

# %%
# Popular Data Types in Python
# List VS Tuple
roles = ["AI Engineer", "Freelance Soft Developer", "Designer"]
ages = (18,19.20,22,23,24,27, 35, 40) # tuple
# Set VS Dictionary
roles = {"AI Engineer","Freelance Soft Developer", "Designer"}
ages ={"AI Engineer": 40000}

# %%
# if-else-elif statement & Indentation
# lets find greatest among three numbers
a = int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input(" Enter third number:"))
if a>b and a>c:
  print("a is the greatest")
elif b>a and b>c:
    print("b is the greatest")
    print("c is the greatest")
# Out:
# Enter first number:10
# Enter second number:20
#  Enter third number:30

# %%
# How can you print the current date & time?
import  datatime
a = datatime.datatime.now()
print(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_574/2125027938.py in <cell line: 0>()
#       1 # How can you print the current date & time?
# ----> 2 import  datatime
#       3 a = datatime.datatime.now()
#       4 print(a)
#
# ModuleNotFoundError: No module named 'datatime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
